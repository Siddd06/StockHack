# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping


def compute_sma(series, window):
    """Compute Simple Moving Average (SMA)."""
    return series.rolling(window=window).mean()

def compute_rsi(series, window=14):
    """Compute Relative Strength Index (RSI)."""
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -delta.clip(upper=0)
    ma_up = up.rolling(window=window).mean()
    ma_down = down.rolling(window=window).mean()
    rsi = 100 - (100 / (1 + ma_up / ma_down))
    return rsi

def generate_features(df):
    """Generate technical indicator features for hourly data."""
    df['SMA_20'] = compute_sma(df['Close'], window=20)
    df['RSI_14'] = compute_rsi(df['Close'], window=14)
    df.dropna(inplace=True)
    return df

def create_lag_features(df, lag=1):
    """Create lag features for forecasting the next hour's closing price."""
    df['Target'] = df['Close'].shift(-lag)
    df.dropna(inplace=True)
    return df

def prepare_lstm_data(df, feature_columns, target_column, sequence_length=60):
    """
    Prepare the dataset for LSTM by creating sequences of fixed length.
    Each sequence consists of multiple hourly observations.
    """
    X_seq, y_seq = [], []
    data_values = df[feature_columns + [target_column]].values
    for i in range(len(data_values) - sequence_length):
        X_seq.append(data_values[i:i+sequence_length, :-1])
        y_seq.append(data_values[i+sequence_length - 1, -1])
    return np.array(X_seq), np.array(y_seq)

def build_lstm_model(input_shape):
    """Build and compile an LSTM model for regression."""
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(LSTM(50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def inverse_transform(scaled_value, scaler, column_index):
    """Convert a scaled value back to the original price scale for a specific column."""
    target_min = scaler.data_min_[column_index]
    target_max = scaler.data_max_[column_index]
    return scaled_value * (target_max - target_min) + target_min


tickers = ["CELH", "CVNA", "UPST", "ALT", "FUBO"]

for ticker in tickers:
    print(f"\nProcessing ticker: {ticker}")

    data = yf.download(ticker, period="240d", interval="60m")
    data.reset_index(inplace=True)

    data.fillna(method='ffill', inplace=True)
    data.sort_values('Datetime', inplace=True)


    data = generate_features(data)
    data = create_lag_features(data, lag=1)

    scaler = MinMaxScaler()
    cols_to_scale = ['Close', 'SMA_20', 'RSI_14', 'Target']
    data[cols_to_scale] = scaler.fit_transform(data[cols_to_scale])

    features = ['Close', 'SMA_20', 'RSI_14']
    target = 'Target'
    X = data[features].values
    y = data[target].values

    tscv = TimeSeriesSplit(n_splits=10)
    rf_predictions = np.zeros(len(y))
    fold = 1
    print("RandomForest Baseline Performance (Hourly Data):")
    for train_index, test_index in tscv.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
        rf_model.fit(X_train, y_train)
        y_pred = rf_model.predict(X_test)
        rf_predictions[test_index] = y_pred
        mse = mean_squared_error(y_test, y_pred)
        print(f"  Fold {fold} MSE: {mse:.5f}")
        fold += 1


    sequence_length = 60
    feature_columns = ['Close', 'SMA_20', 'RSI_14']
    target_column = 'Target'

    X_lstm, y_lstm = prepare_lstm_data(data, feature_columns, target_column, sequence_length)

    split_index = int(len(X_lstm) * 0.8)
    X_train_lstm, X_test_lstm = X_lstm[:split_index], X_lstm[split_index:]
    y_train_lstm, y_test_lstm = y_lstm[:split_index], y_lstm[split_index:]

    input_shape = (X_train_lstm.shape[1], X_train_lstm.shape[2])
    lstm_model = build_lstm_model(input_shape)
    early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
    lstm_model.fit(X_train_lstm, y_train_lstm, epochs=50, batch_size=32, verbose=1, callbacks=[early_stop])

    y_pred_lstm = lstm_model.predict(X_test_lstm)
    lstm_mse = mean_squared_error(y_test_lstm, y_pred_lstm)
    print(f"LSTM Test MSE (Hourly Data): {lstm_mse:.5f}")

    actual_y = np.array([inverse_transform(val, scaler, 0) for val in y])
    actual_rf_predictions = np.array([inverse_transform(val, scaler, 0) for val in rf_predictions])
    actual_lstm_predictions = np.array([inverse_transform(val, scaler, 0) for val in y_pred_lstm.flatten()])


    plt.figure(figsize=(12, 6))
    plt.plot(data['Datetime'], actual_y, label="Actual")
    plt.plot(data['Datetime'], actual_rf_predictions, label="RF Predictions")
    plt.xlabel("Datetime")
    plt.ylabel("Price")
    plt.title(f"{ticker} - RandomForest Predictions vs Actual Hourly Closing Prices")
    plt.legend()
    plt.show()

    test_datetimes = data['Datetime'].iloc[-len(actual_lstm_predictions):]
    plt.figure(figsize=(12, 6))
    plt.plot(test_datetimes, actual_y[-len(actual_lstm_predictions):], label="Actual")
    plt.plot(test_datetimes, actual_lstm_predictions, label="LSTM Predictions")
    plt.xlabel("Datetime")
    plt.ylabel("Price")
    plt.title(f"{ticker} - LSTM Predictions vs Actual Hourly Closing Prices")
    plt.legend()
    plt.show()


    n_hours = 72
    last_row = data.iloc[-1].copy()
    future_predictions_rf = []
    current_features = last_row[features].values.reshape(1, -1)

    for i in range(n_hours):
        pred_scaled = rf_model.predict(current_features)[0]
        pred_actual = inverse_transform(pred_scaled, scaler, 0)
        future_predictions_rf.append(pred_actual)
        current_features[0, 0] = pred_scaled

    print(f"{ticker} - RandomForest Future Predictions (Actual Price) for next {n_hours} hours:")
    print(future_predictions_rf)

    last_sequence = data[feature_columns + [target_column]].values[-sequence_length:]
    future_predictions_lstm = []
    current_sequence = last_sequence.copy()

    for i in range(n_hours):
        input_seq = current_sequence[:, :-1].reshape(1, sequence_length, len(feature_columns))
        pred_scaled = lstm_model.predict(input_seq)[0, 0]
        pred_actual = inverse_transform(pred_scaled, scaler, 0)
        future_predictions_lstm.append(pred_actual)

        new_row = current_sequence[-1].copy()
        new_row[0] = pred_scaled
        new_row[-1] = pred_scaled
        current_sequence = np.vstack([current_sequence[1:], new_row])

    print(f"{ticker} - LSTM Future Predictions (Actual Price) for next {n_hours} hours:")
    print(future_predictions_lstm)
# Out:
# Processing ticker: CELH
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-7fbc76675e65>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance (Hourly Data):
#   Fold 1 MSE: 0.00658
#   Fold 2 MSE: 0.00128
#   Fold 3 MSE: 0.00442
#   Fold 4 MSE: 0.01054
#   Fold 5 MSE: 0.00262
#   Fold 6 MSE: 0.00042
#   Fold 7 MSE: 0.00017
#   Fold 8 MSE: 0.00007
#   Fold 9 MSE: 0.00003
#   Fold 10 MSE: 0.00121
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0794
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0040
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 0.0035
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0031
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0025
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 0.0030
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 0.0029
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 0.0027
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0027
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0029
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0024
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0025
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0025
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0025
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0020
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0022
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0017
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0022
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0018
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0020
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0021
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0017
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0019
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0016
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0017
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0019
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0015
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0019
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0017
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0018
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0016
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0016
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0015
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0015
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0017
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0016
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0015
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0014
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# LSTM Test MSE (Hourly Data): 0.00021
# CELH - RandomForest Future Predictions (Actual Price) for next 72 hours:
# [32.06407993316649, 31.41156818389893, 31.032403945922862, 30.999750289916996, 31.102242431640633, 30.98517618179322, 30.97384632110596, 30.867650260925295, 30.67909997940064, 30.666754970550546, 30.705555000305182, 30.749304943084724, 30.77224992752076, 30.755749969482423, 30.782299919128427, 30.726299953460696, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124, 30.72680492401124]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# UPST - LSTM Future Predictions (Actual Price) for next 72 hours:
# [74.85842689274432, 74.14444382089232, 73.56015461343077, 73.0798671764494, 72.68263558911144, 72.35194194880114, 72.07479420599407, 71.84109857112344, 71.64302320487513, 71.47437934162531, 71.33032492601615, 71.20695057581906, 71.10112704193693, 71.01017833698029, 70.9320429918364, 70.86490795967461, 70.80723476566027, 70.75771156581254, 70.71520084757663, 70.67873071325243, 70.64745565542376, 70.62063912381564, 70.5976796750083, 70.5780150901528, 70.56116159954195, 70.54673567403847, 70.53437121764773, 70.52374571723158, 70.51462818365053, 70.50678326947946, 70.50004100157798, 70.49420525709183, 70.4891540040228, 70.48477392694394, 70.48095171042837, 70.47761326362001, 70.47471500366237, 70.47216104827112, 70.46992960601801, 70.4679553026183, 70.46620327178675, 70.46465172209514, 70.46327450382955, 70.46207161698999, 70.46098640386299, 70.46000143130595, 70.45914284903279, 70.45835835761568, 70.45766974848289, 70.45703779706355, 70.45646686164332, 70.45595258393655, 70.45550368051454, 70.45507221023513, 70.45469303938353, 70.45435745138843, 70.45405237139289, 70.45377344111125, 70.45352066054352, 70.45330274626099, 70.45310226512106, 70.45291050055243, 70.45272745255511, 70.45257927084299, 70.45244416398782, 70.4523134154183, 70.45220009999139, 70.45209985942142, 70.45202141027971, 70.45192988628105, 70.45186015371064, 70.45180349599718]
#
# Processing ticker: ALT
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-7fbc76675e65>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance (Hourly Data):
#   Fold 1 MSE: 0.00895
#   Fold 2 MSE: 0.00145
#   Fold 3 MSE: 0.00245
#   Fold 4 MSE: 0.00106
#   Fold 5 MSE: 0.00070
#   Fold 6 MSE: 0.00060
#   Fold 7 MSE: 0.00217
#   Fold 8 MSE: 0.00199
#   Fold 9 MSE: 0.00075
#   Fold 10 MSE: 0.00045
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0504
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0071
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0071
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0052
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0047
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0056
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0044
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0042
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0041
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0039
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0035
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0037
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0037
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0033
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0031
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0035
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0034
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0029
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 0.0037
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0030
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0029
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0031
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0022
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0026
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0024
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0024
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0025
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0022
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0024
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0024
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0022
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0024
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0025
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0022
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss:
#
# Processing ticker: FUBO
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-7fbc76675e65>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance (Hourly Data):
#   Fold 1 MSE: 0.00032
#   Fold 2 MSE: 0.00013
#   Fold 3 MSE: 0.00007
#   Fold 4 MSE: 0.00004
#   Fold 5 MSE: 0.00144
#   Fold 6 MSE: 0.00003
#   Fold 7 MSE: 0.00004
#   Fold 8 MSE: 0.00006
#   Fold 9 MSE: 0.13050
#   Fold 10 MSE: 0.00089
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - loss: 0.0024
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.9142e-04
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 2.9969e-04
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.8120e-04
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 2.1459e-04
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 2.1197e-04
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 2.0529e-04
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 1.9522e-04
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 1.5974e-04
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 1.6830e-04
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.5274e-04
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.5127e-04
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 1.5116e-04
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 1.9036e-04
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 1.4244e-04
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.2716e-04
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 1.2737e-04
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 1.3534e-04
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 1.1381e-04
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 1.2609e-04
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 1.2505e-04
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 1.3192e-04
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 1.3246e-04
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.1784e-04
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.3239e-04
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 8.6466e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 9.1400e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.0966e-04
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 9.3297e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 9.4888e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 1.1199e-04
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 1.0749e-04
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.0663e-04
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 8.9840e-05
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 9.5980e-05
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 9.3887e-05
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 9.3168e-05
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 8.7016e-05
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 1.0474e-04
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 1.1358e-04
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 9.0133e-05
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 8.0786e-05
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 9.7052e-05
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 9.9687e-05
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 9.7119e-05
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 7.2967e-05
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 1.1012e-04
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step