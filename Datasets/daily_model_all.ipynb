# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping


def compute_sma(series, window):
    """Compute Simple Moving Average (SMA)."""
    return series.rolling(window=window).mean()

def compute_rsi(series, window=14):
    """Compute Relative Strength Index (RSI)."""
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ma_up = up.rolling(window=window).mean()
    ma_down = down.rolling(window=window).mean()
    rsi = 100 - (100 / (1 + ma_up / ma_down))
    return rsi

def generate_features(df):
    """Generate technical indicator features."""
    df['SMA_20'] = compute_sma(df['Close'], window=20)
    df['RSI_14'] = compute_rsi(df['Close'], window=14)
    df.dropna(inplace=True)
    return df

def create_lag_features(df, lag=1):
    """Create lag feature for forecasting next-day closing price."""
    df['Target'] = df['Close'].shift(-lag)
    df.dropna(inplace=True)
    return df

def prepare_lstm_data(df, feature_columns, target_column, sequence_length=60):
    """
    Prepare the dataset for LSTM by creating sequences of a fixed length.
    Each sequence will consist of multiple feature observations.
    """
    X_seq, y_seq = [], []
    data_values = df[feature_columns + [target_column]].values
    for i in range(len(data_values) - sequence_length):
        X_seq.append(data_values[i:i+sequence_length, :-1])
        y_seq.append(data_values[i+sequence_length - 1, -1])
    return np.array(X_seq), np.array(y_seq)

def build_lstm_model(input_shape):
    """Build and compile an LSTM model for regression."""
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(LSTM(50))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def inverse_transform(scaled_value, scaler, column_index):
    """Convert a scaled value back to the original price scale for a specific column."""
    target_min = scaler.data_min_[column_index]
    target_max = scaler.data_max_[column_index]
    return scaled_value * (target_max - target_min) + target_min

tickers = ["CELH", "CVNA", "UPST", "ALT", "FUBO"]


for ticker in tickers:
    print(f"\nProcessing ticker: {ticker}")


    data = yf.download(ticker, start="2019-01-01", end="2025-02-23")
    data.reset_index(inplace=True)
    data.fillna(method='ffill', inplace=True)
    data.sort_values('Date', inplace=True)

    data = generate_features(data)
    data = create_lag_features(data, lag=1)

    scaler = MinMaxScaler()
    cols_to_scale = ['Close', 'SMA_20', 'RSI_14', 'Target']
    data[cols_to_scale] = scaler.fit_transform(data[cols_to_scale])


    features = ['Close', 'SMA_20', 'RSI_14']
    target = 'Target'
    X = data[features].values
    y = data[target].values

    tscv = TimeSeriesSplit(n_splits=10)
    rf_predictions = np.zeros(len(y))
    fold = 1
    print("RandomForest Baseline Performance:")
    for train_index, test_index in tscv.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
        rf_model.fit(X_train, y_train)
        y_pred = rf_model.predict(X_test)
        rf_predictions[test_index] = y_pred
        mse = mean_squared_error(y_test, y_pred)
        print(f"  Fold {fold} MSE: {mse:.5f}")
        fold += 1

    sequence_length = 60
    feature_columns = ['Close', 'SMA_20', 'RSI_14']
    target_column = 'Target'

    X_lstm, y_lstm = prepare_lstm_data(data, feature_columns, target_column, sequence_length)


    split_index = int(len(X_lstm) * 0.8)
    X_train_lstm, X_test_lstm = X_lstm[:split_index], X_lstm[split_index:]
    y_train_lstm, y_test_lstm = y_lstm[:split_index], y_lstm[split_index:]

    input_shape = (X_train_lstm.shape[1], X_train_lstm.shape[2])
    lstm_model = build_lstm_model(input_shape)
    early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
    lstm_model.fit(X_train_lstm, y_train_lstm, epochs=50, batch_size=32, verbose=0, callbacks=[early_stop])

    y_pred_lstm = lstm_model.predict(X_test_lstm)
    lstm_mse = mean_squared_error(y_test_lstm, y_pred_lstm)
    print(f"LSTM Test MSE: {lstm_mse:.5f}")

    actual_y = np.array([inverse_transform(val, scaler, 0) for val in y])
    actual_rf_predictions = np.array([inverse_transform(val, scaler, 0) for val in rf_predictions])
    actual_lstm_predictions = np.array([inverse_transform(val, scaler, 0) for val in y_pred_lstm.flatten()])

    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], actual_y, label="Actual")
    plt.plot(data['Date'], actual_rf_predictions, label="RF Predictions")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.title(f"{ticker} - RandomForest Predictions vs Actual Closing Prices")
    plt.legend()
    plt.show()

    test_dates = data['Date'].iloc[-len(actual_lstm_predictions):]
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates, actual_y[-len(actual_lstm_predictions):], label="Actual")
    plt.plot(test_dates, actual_lstm_predictions, label="LSTM Predictions")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.title(f"{ticker} - LSTM Predictions vs Actual Closing Prices")
    plt.legend()
    plt.show()

    last_row = data.iloc[-1].copy()
    future_predictions_rf = []
    current_features = last_row[features].values.reshape(1, -1)

    for i in range(3):
        pred_scaled = rf_model.predict(current_features)[0]
        pred_actual = inverse_transform(pred_scaled, scaler, 0)
        future_predictions_rf.append(pred_actual)
        current_features[0, 0] = pred_scaled

    print(f"{ticker} - RandomForest Future Predictions (Feb 24th to Feb 26th):", future_predictions_rf)

    last_sequence = data[feature_columns + [target_column]].values[-sequence_length:]
    future_predictions_lstm = []
    current_sequence = last_sequence.copy()

    for i in range(3):
        input_seq = current_sequence[:, :-1].reshape(1, sequence_length, len(feature_columns))
        pred_scaled = lstm_model.predict(input_seq)[0, 0]
        pred_actual = inverse_transform(pred_scaled, scaler, 0)
        future_predictions_lstm.append(pred_actual)
        new_row = current_sequence[-1].copy()
        new_row[0] = pred_scaled
        new_row[-1] = pred_scaled
        current_sequence = np.vstack([current_sequence[1:], new_row])

    print(f"{ticker} - LSTM Future Predictions (Feb 24th to Feb 26th):", future_predictions_lstm)
# Out:
# Processing ticker: CELH
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-da977673b514>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance:
#   Fold 1 MSE: 0.00001
#   Fold 2 MSE: 0.00092
#   Fold 3 MSE: 0.00799
#   Fold 4 MSE: 0.00452
#   Fold 5 MSE: 0.00029
#   Fold 6 MSE: 0.00046
#   Fold 7 MSE: 0.00232
#   Fold 8 MSE: 0.00718
#   Fold 9 MSE: 0.02461
#   Fold 10 MSE: 0.00027
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# LSTM Test MSE: 0.00153
# CELH - RandomForest Future Predictions (Feb 24th to Feb 26th): [25.842866859436043, 26.29730003356933, 27.3334998512268]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# CELH - LSTM Future Predictions (Feb 24th to Feb 26th): [23.713554332063083, 23.93274726223705, 23.93209996513076]
#
# Processing ticker: CVNA
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-da977673b514>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance:
#   Fold 1 MSE: 0.00072
#   Fold 2 MSE: 0.02137
#   Fold 3 MSE: 0.02358
#   Fold 4 MSE: 0.00585
#   Fold 5 MSE: 0.00160
#   Fold 6 MSE: 0.00205
#   Fold 7 MSE: 0.00006
#   Fold 8 MSE: 0.00008
#   Fold 9 MSE: 0.00022
#   Fold 10 MSE: 0.00067
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# LSTM Test MSE: 0.00110
# CVNA - RandomForest Future Predictions (Feb 24th to Feb 26th): [251.94450057983386, 253.54150192260755, 255.44909912109378]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# CVNA - LSTM Future Predictions (Feb 24th to Feb 26th): [278.4085681970819, 276.7515918941637, 275.0989395053683]
#
# Processing ticker: UPST
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-da977673b514>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance:
#   Fold 1 MSE: 0.06848
#   Fold 2 MSE: 0.00806
#   Fold 3 MSE: 0.00191
#   Fold 4 MSE: 0.00014
#   Fold 5 MSE: 0.00013
#   Fold 6 MSE: 0.00022
#   Fold 7 MSE: 0.00003
#   Fold 8 MSE: 0.00002
#   Fold 9 MSE: 0.00003
#   Fold 10 MSE: 0.00038
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# LSTM Test MSE: 0.00032
# UPST - RandomForest Future Predictions (Feb 24th to Feb 26th): [71.45079940795904, 73.7091501235962, 74.23100002288817]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# UPST - LSTM Future Predictions (Feb 24th to Feb 26th): [81.03028479412899, 81.94001940889422, 82.55603893290626]
#
# Processing ticker: ALT
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-da977673b514>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance:
#   Fold 1 MSE: 0.00011
#   Fold 2 MSE: 0.15639
#   Fold 3 MSE: 0.00272
#   Fold 4 MSE: 0.00091
#   Fold 5 MSE: 0.00077
#   Fold 6 MSE: 0.00121
#   Fold 7 MSE: 0.00057
#   Fold 8 MSE: 0.00029
#   Fold 9 MSE: 0.00039
#   Fold 10 MSE: 0.00020
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# LSTM Test MSE: 0.00064
# ALT - RandomForest Future Predictions (Feb 24th to Feb 26th): [6.720849952697749, 6.691799945831296, 6.748749952316281]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ALT - LSTM Future Predictions (Feb 24th to Feb 26th): [7.008729166124617, 7.135603080981539, 7.248717168046028]
#
# Processing ticker: FUBO
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-da977673b514>:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# RandomForest Baseline Performance:
#   Fold 1 MSE: 0.00029
#   Fold 2 MSE: 0.00131
#   Fold 3 MSE: 0.03402
#   Fold 4 MSE: 0.00089
#   Fold 5 MSE: 0.00051
#   Fold 6 MSE: 0.00012
#   Fold 7 MSE: 0.00004
#   Fold 8 MSE: 0.00001
#   Fold 9 MSE: 0.00000
#   Fold 10 MSE: 0.00004
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# LSTM Test MSE: 0.00015
# FUBO - RandomForest Future Predictions (Feb 24th to Feb 26th): [4.045900101661684, 3.8812999773025516, 3.962400102615358]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# FUBO - LSTM Future Predictions (Feb 24th to Feb 26th): [3.7620265375720088, 3.6494237177011684, 3.552311185978411]
